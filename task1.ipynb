# %% [markdown]
# <a href="https://colab.research.google.com/github/anpixelartist/task1/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Handle missing values using mean/median/imputation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(y='Age', data =df)
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# there are outliers in the data according to the box plot of the age feature. So choosing the mean would not be a good choice instead we should choose the median value which is less affected by the extreme values.

# %%
median_age = df['Age'].median()
median_age
# Out:
# 28.0

# %%
df['Age'].fillna(median_age, inplace = True)
# Out:
# /tmp/ipython-input-955302876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_age, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.fillna({'Cabin':'missing'},inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Embarked_mode = df['Embarked'].mode()[0]
Embarked_mode
# Out:
# 'S'

# %%
df.fillna({'Embarked':'Embarked_mode'},inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          148
# Embarked         4
# dtype: int64

# %%
df_encoded = pd.get_dummies(df, columns=['Sex','Survived','Pclass','Embarked'])
df_encoded.head()
# Out:
#    PassengerId                                               Name   Age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare    Cabin  Sex_female  Sex_male  \
# 0      1      0         A/5 21171   7.2500  missing       False      True
# 1      1      0          PC 17599  71.2833      C85        True     False
# 2      0      0  STON/O2. 3101282   7.9250  missing        True     False
# 3      1      0            113803  53.1000     C123        True     False
# 4      0      0            373450   8.0500  missing       False      True
#
#    Survived_0  Survived_1  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0        True       False     False     False      True       False
# 1       False        True      True     False     False        True
# 2       False        True     False     False      True       False
# 3       False        True      True     False     False       False
# 4        True       False     False     False      True       False
#
#    Embarked_Embarked_mode  Embarked_Q  Embarked_S
# 0                   False       False        True
# 1                   False       False       False
# 2                   False       False        True
# 3                   False       False        True
# 4                   False       False        True

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_encoded['fare_Normalised'] = scaler.fit_transform(df_encoded[['Fare']].values.reshape(-1,1))
df_encoded.head()
# Out:
#    PassengerId                                               Name   Age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare    Cabin  Sex_female  Sex_male  \
# 0      1      0         A/5 21171   7.2500  missing       False      True
# 1      1      0          PC 17599  71.2833      C85        True     False
# 2      0      0  STON/O2. 3101282   7.9250  missing        True     False
# 3      1      0            113803  53.1000     C123        True     False
# 4      0      0            373450   8.0500  missing       False      True
#
#    Survived_0  Survived_1  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0        True       False     False     False      True       False
# 1       False        True      True     False     False        True
# 2       False        True     False     False      True       False
# 3       False        True      True     False     False       False
# 4        True       False     False     False      True       False
#
#    Embarked_Embarked_mode  Embarked_Q  Embarked_S  fare_Normalised
# 0                   False       False        True         0.014151
# 1                   False       False       False         0.139136
# 2                   False       False        True         0.015469
# 3                   False       False        True         0.103644
# 4                   False       False        True         0.015713

# %%
df_encoded['Age_normalised']=scaler.fit_transform(df_encoded[['Age']].values.reshape(-1,1))
df_encoded.head()
# Out:
#    PassengerId                                               Name   Age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare    Cabin  Sex_female  Sex_male  \
# 0      1      0         A/5 21171   7.2500  missing       False      True
# 1      1      0          PC 17599  71.2833      C85        True     False
# 2      0      0  STON/O2. 3101282   7.9250  missing        True     False
# 3      1      0            113803  53.1000     C123        True     False
# 4      0      0            373450   8.0500  missing       False      True
#
#    ...  Survived_1  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0  ...       False     False     False      True       False
# 1  ...        True      True     False     False        True
# 2  ...        True     False     False      True       False
# 3  ...        True      True     False     False       False
# 4  ...       False     False     False      True       False
#
#    Embarked_Embarked_mode  Embarked_Q  Embarked_S  fare_Normalised  \
# 0                   False       False        True         0.014151
# 1                   False       False       False         0.139136
# 2                   False       False        True         0.015469
# 3                   False       False        True         0.103644
# 4                   False       False        True         0.015713
#
#    Age_normalised
# 0        0.271174
# 1        0.472229
# 2        0.321438
# 3        0.434531
# 4        0.434531
#
# [5 rows x 21 columns]

# %%
sns.boxplot(y='fare_Normalised', data = df_encoded)
# Out:
# <Axes: ylabel='fare_Normalised'>

# %%
Q1= df_encoded['fare_Normalised'].quantile(0.25)
Q3=df_encoded['fare_Normalised'].quantile(0.75)
IQR = Q3-Q1
print(f'IQR: {IQR}')
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR
# Out:
# IQR: 0.04506789775011848

# %%
# Identify the indices of the rows that are outliers
outlier_indices = df_encoded[(df_encoded['fare_Normalised'] < lower_bound) | (df_encoded['fare_Normalised'] > upper_bound)].index

# Drop the rows with the outlier indices
df_encoded.drop(outlier_indices, inplace=True)

df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 775 entries, 0 to 890
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PassengerId             775 non-null    int64
#  1   Name                    775 non-null    object
#  2   Age                     775 non-null    float64
#  3   SibSp                   775 non-null    int64
#  4   Parch                   775 non-null    int64
#  5   Ticket                  775 non-null    object
#  6   Fare                    775 non-null    float64
#  7   Cabin                   775 non-null    object
#  8   Sex_female              775 non-null    bool
#  9   Sex_male                775 non-null    bool
#  10  Survived_0              775 non-null    bool
#  11  Survived_1              775 non-null    bool
#  12  Pclass_1                775 non-null    bool
#  13  Pclass_2                775 non-null    bool
#  14  Pclass_3                775 non-null    bool
#  15  Embarked_C              775 non-null    bool
#  16  Embarked_Embarked_mode  775 non-null    bool
#  17  Embarked_Q              775 non-null    bool
#  18  Embarked_S              775 non-null    bool
#  19  fare_Normalised         775 non-null    float64
#  20  Age_normalised          775 non-null    float64
# dtypes: bool(11), float64(4), int64(3), object(3)
# memory usage: 74.9+ KB

# %%
sns.boxplot(y='Age_normalised', data = df_encoded)
# Out:
# <Axes: ylabel='Age_normalised'>

# %%
df_encoded.drop(['Fare','Age'], axis =1,inplace = True)
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 775 entries, 0 to 890
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PassengerId             775 non-null    int64
#  1   Name                    775 non-null    object
#  2   SibSp                   775 non-null    int64
#  3   Parch                   775 non-null    int64
#  4   Ticket                  775 non-null    object
#  5   Cabin                   775 non-null    object
#  6   Sex_female              775 non-null    bool
#  7   Sex_male                775 non-null    bool
#  8   Survived_0              775 non-null    bool
#  9   Survived_1              775 non-null    bool
#  10  Pclass_1                775 non-null    bool
#  11  Pclass_2                775 non-null    bool
#  12  Pclass_3                775 non-null    bool
#  13  Embarked_C              775 non-null    bool
#  14  Embarked_Embarked_mode  775 non-null    bool
#  15  Embarked_Q              775 non-null    bool
#  16  Embarked_S              775 non-null    bool
#  17  fare_Normalised         775 non-null    float64
#  18  Age_normalised          775 non-null    float64
# dtypes: bool(11), float64(2), int64(3), object(3)
# memory usage: 62.8+ KB

# %%
age_q1= df_encoded['Age_normalised'].quantile(0.25)
age_q3= df_encoded['Age_normalised'].quantile(0.75)
ageIQR = age_q3-age_q1
age_ul= age_q3+ageIQR*1.5
age_ll= age_q1-ageIQR*1.5
index = df_encoded[(df_encoded['Age_normalised']>=age_ll)&(df_encoded['Age_normalised']<=age_ul)].index
index
# Out:
# Index([  0,   2,   3,   4,   5,   8,   9,  10,  12,  13,
#        ...
#        881, 882, 883, 884, 885, 886, 887, 888, 889, 890],
#       dtype='int64', length=708)

# %%
outlierIndex = df_encoded['Age_normalised'].index.difference(index)
df_encoded.drop( outlierIndex , inplace=True)
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 708 entries, 0 to 890
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PassengerId             708 non-null    int64
#  1   Name                    708 non-null    object
#  2   SibSp                   708 non-null    int64
#  3   Parch                   708 non-null    int64
#  4   Ticket                  708 non-null    object
#  5   Cabin                   708 non-null    object
#  6   Sex_female              708 non-null    bool
#  7   Sex_male                708 non-null    bool
#  8   Survived_0              708 non-null    bool
#  9   Survived_1              708 non-null    bool
#  10  Pclass_1                708 non-null    bool
#  11  Pclass_2                708 non-null    bool
#  12  Pclass_3                708 non-null    bool
#  13  Embarked_C              708 non-null    bool
#  14  Embarked_Embarked_mode  708 non-null    bool
#  15  Embarked_Q              708 non-null    bool
#  16  Embarked_S              708 non-null    bool
#  17  fare_Normalised         708 non-null    float64
#  18  Age_normalised          708 non-null    float64
# dtypes: bool(11), float64(2), int64(3), object(3)
# memory usage: 57.4+ KB

# %%
sns.boxplot(y='Age_normalised', data = df_encoded)
# Out:
# <Axes: ylabel='Age_normalised'>

# %% [markdown]
# # Titanic Dataset Analysis and Preprocessing
#
# This notebook performs an initial analysis and preprocessing steps on the Titanic dataset to prepare it for machine learning model training.
#
# ## Data Source
#
# The dataset used in this notebook is the classic Titanic dataset, typically found as "Titanic-Dataset.csv". It contains information about passengers on the ill-fated Titanic voyage, including whether they survived.
#
# ## Steps Performed
#
# The following steps were performed in this notebook:
#
# 1.  **Import and Explore Data**:
#     *   The dataset was imported into a pandas DataFrame.
#     *   Basic information about the dataset was explored, including checking for null values (`df.info()`) and examining data types. The head of the DataFrame was also displayed.
#
# 2.  **Handle Missing Values**:
#     *   Missing values in the 'Age' column were imputed with the median age, as a box plot revealed outliers that would skew the mean.
#     *   Missing values in the 'Cabin' column were filled with the string 'missing'.
#     *   Missing values in the 'Embarked' column were filled with the mode of the column.
#
# 3.  **Convert Categorical Features**:
#     *   Categorical features ('Sex', 'Survived', 'Pclass', 'Embarked') were converted into numerical format using one-hot encoding (`pd.get_dummies`).
#
# 4.  **Normalize Numerical Features**:
#     *   The 'Fare' and 'Age' features were normalized using `MinMaxScaler` to scale their values to a range between 0 and 1. New columns 'fare\_Normalised' and 'Age\_normalised' were created for the normalized values.
#
# 5.  **Visualize and Remove Outliers**:
#     *   Box plots were generated for the normalized 'Fare' and 'Age' columns ('fare\_Normalised' and 'Age\_normalised') to visualize the presence of outliers.
#     *   Outliers in both the 'fare\_Normalised' and 'Age\_normalised' columns were identified using the Interquartile Range (IQR) method (1.5 * IQR rule).
#     *   Rows containing these outliers were directly dropped from the DataFrame.
#
# ## Libraries Used
#
# *   `pandas` for data manipulation and analysis.
# *   `matplotlib.pyplot` and `seaborn` for data visualization (specifically box plots).
# *   `sklearn.preprocessing.MinMaxScaler` for feature normalization.
#
# ## How to Run the Notebook
#
# 1.  Ensure you have the "Titanic-Dataset.csv" file in the appropriate directory (`/content/`).
# 2.  Run the cells sequentially in the notebook.
#
# This notebook provides a clean and preprocessed dataset (`df_encoded`) ready for building machine learning models to predict survival on the Titanic.
